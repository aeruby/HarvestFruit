# %%
pip install tensorflow numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras import layers, models

# Confirm GPU
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

ROWS, COLS = 5, 5
FRUIT = 'f'
HARVESTED = 'h'
EMPTY = '.'
GARDENER = 'G'

actions = ['up', 'down', 'left', 'right']

def create_garden():
    garden = [[EMPTY for _ in range(COLS)] for _ in range(ROWS)]
    for r in range(ROWS):
        for c in range(COLS):
            if random.random() < 0.2:
                garden[r][c] = FRUIT
    return garden

def print_garden(garden, pos):
    for r in range(ROWS):
        row_str = ''
        for c in range(COLS):
            if pos == [r, c]:
                row_str += GARDENER
            else:
                row_str += garden[r][c]
        print(row_str)
    print()

def valid_move(r, c):
    return 0 <= r < ROWS and 0 <= c < COLS

def move_agent(pos, action):
    r, c = pos
    if action == 'up' and valid_move(r - 1, c):
        return [r - 1, c]
    elif action == 'down' and valid_move(r + 1, c):
        return [r + 1, c]
    elif action == 'left' and valid_move(r, c - 1):
        return [r, c - 1]
    elif action == 'right' and valid_move(r, c + 1):
        return [r, c + 1]
    return pos

class DQNAgent:
    def __init__(self):
        self.model = self.build_model()
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.05
        self.epsilon_decay = 0.99  # slower decay for longer exploration
        self.gamma = 0.95
        self.memory = []
        self.batch_size = 32

    def build_model(self):
        model = models.Sequential()
        model.add(layers.Flatten(input_shape=(ROWS, COLS, 1)))
        model.add(layers.Dense(64, activation='relu'))
        model.add(layers.Dense(32, activation='relu'))
        model.add(layers.Dense(len(actions), activation='linear'))
        model.compile(optimizer='adam', loss='mse')
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > 1000:
            self.memory.pop(0)

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return random.randrange(len(actions))
        q_values = self.model.predict(state[np.newaxis], verbose=0)[0]
        return np.argmax(q_values)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target += self.gamma * np.amax(self.model.predict(next_state[np.newaxis], verbose=0)[0])
            target_f = self.model.predict(state[np.newaxis], verbose=0)
            target_f[0][action] = target
            self.model.fit(state[np.newaxis], target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def encode_state(garden, pos):
    mapping = {EMPTY: 0, FRUIT: 1, HARVESTED: 2}
    state = np.zeros((ROWS, COLS), dtype=np.float32)
    for r in range(ROWS):
        for c in range(COLS):
            state[r][c] = mapping[garden[r][c]]
    r, c = pos
    state[r][c] = 3  # Gardener mark
    return state.reshape((ROWS, COLS, 1))

episodes = 20  # increased episodes for better training
agent = DQNAgent()

for e in range(1, episodes + 1):
    garden = create_garden()
    pos = [0, 0]  # Gardener starts at top-left corner, no fruit here
    total_harvested = 0

    max_steps = 25
    steps = 0

    print(f"Episode {e} starting:")
    print_garden(garden, pos)

    done = False
    while not done and steps < max_steps:
        state = encode_state(garden, pos)
        action_idx = agent.act(state)
        action = actions[action_idx]

        new_pos = move_agent(pos, action)
        r, c = new_pos

        # Step penalty to encourage efficient movement
        reward = -0.01

        if garden[r][c] == FRUIT:
            garden[r][c] = HARVESTED
            total_harvested += 1
            reward = 1
            print(f"Harvested fruit at ({r},{c})")

        pos = new_pos
        next_state = encode_state(garden, pos)
        done = not any(FRUIT in row for row in garden)

        agent.remember(state, action_idx, reward, next_state, done)
        agent.replay()

        steps += 1
        print(f"Step {steps}: Gardener at {pos}, action: {action}")
        print_garden(garden, pos)

        # Safety break to avoid infinite loops
        if steps > 200:
            print("Max steps reached, ending episode early.")
            break

    print(f"Episode {e} finished in {steps} steps. Total harvested: {total_harvested}\n{'='*30}\n")
# Out:
# Num GPUs Available: 1
# Episode 1 starting:
# G....
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Harvested fruit at (0,0)
# Step 1: Gardener at [0, 0], action: up
# G....
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 2: Gardener at [0, 1], action: right
# hG...
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 3: Gardener at [0, 2], action: right
# h.G..
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 4: Gardener at [0, 2], action: up
# h.G..
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 5: Gardener at [0, 2], action: up
# h.G..
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 6: Gardener at [0, 1], action: left
# hG...
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 7: Gardener at [0, 0], action: left
# G....
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 8: Gardener at [0, 0], action: up
# G....
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 9: Gardener at [0, 0], action: left
# G....
# .f..f
# f.ff.
# ..fff
# ..f..
#
# Step 10: Gardener at [1, 0], action: down
# h....
# Gf..f
# f.ff.
# ..fff
# ..f..
#
# Harvested fruit at (2,0)
# Step 11: Gardener at [2, 0], action: down
# h....
# .f..f
# G.ff.
# ..fff
# ..f..
#
# Step 12: Gardener at [3, 0], action: down
# h....
# .f..f
# h.ff.
# G.fff
# ..f..
#
# Step 13: Gardener at [3, 0], action: left
# h....
# .f..f
# h.ff.
# G.fff
# ..f..
#
# Step 14: Gardener at [4, 0], action: down
# h....
# .f..f
# h.ff.
# ..fff
# G.f..
#
# Step 15: Gardener at [4, 0], action: left
# h....
# .f..f
# h.ff.
# ..fff
# G.f..
#
# Step 16: Gardener at [3, 0], action: up
# h....
# .f..f
# h.ff.
# G.fff
# ..f..
#
# Step 17: Gardener at [3, 1], action: right
# h....
# .f..f
# h.ff.
# .Gfff
# ..f..
#
# Step 18: Gardener at [2, 1], action: up
# h....
# .f..f
# hGff.
# ..fff
# ..f..
#
# Harvested fruit at (2,2)
# Step 19: Gardener at [2, 2], action: right
# h....
# .f..f
# h.Gf.
# ..fff
# ..f..
#
# Harvested fruit at (3,2)
# Step 20: Gardener at [3, 2], action: down
# h....
# .f..f
# h.hf.
# ..Gff
# ..f..
#
# Step 21: Gardener at [3, 1], action: left
# h....
# .f..f
# h.hf.
# .Ghff
# ..f..
#
# Step 22: Gardener at [3, 0], action: left
# h....
# .f..f
# h.hf.
# G.hff
# ..f..
#
# Step 23: Gardener at [3, 0], action: left
# h....
# .f..f
# h.hf.
# G.hff
# ..f..
#
# Step 24: Gardener at [3, 0], action: left
# h....
# .f..f
# h.hf.
# G.hff
# ..f..
#
# Step 25: Gardener at [4, 0], action: down
# h....
# .f..f
# h.hf.
# ..hff
# G.f..
#
# Episode 1 finished in 25 steps. Total harvested: 4
# ==============================
#
# Episode 2 starting:
# G....
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 1: Gardener at [0, 0], action: up
# G....
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 2: Gardener at [0, 1], action: right
# .G...
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 3: Gardener at [0, 2], action: right
# ..G..
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 4: Gardener at [0, 2], action: up
# ..G..
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 5: Gardener at [0, 2], action: up
# ..G..
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 6: Gardener at [0, 1], action: left
# .G...
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 7: Gardener at [0, 0], action: left
# G....
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 8: Gardener at [0, 1], action: right
# .G...
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 9: Gardener at [0, 2], action: right
# ..G..
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 10: Gardener at [0, 3], action: right
# ...G.
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 11: Gardener at [0, 3], action: up
# ...G.
# .f.ff
# .....
# ffff.
# ..f..
#
# Step 12: Gardener at [0, 3], action: up
# ...G.
# .f.ff
# .....
# ffff.
# ..f..
#
# Harvested fruit at (1,3)
# Step 13: Gardener at [1, 3], action: down
# .....
# .f.Gf
# .....
# ffff.
# ..f..
#
# Step 14: Gardener at [1, 2], action: left
# .....
# .fGhf
# .....
# ffff.
# ..f..
#
# Harvested fruit at (1,1)
# Step 15: Gardener at [1, 1], action: left
# .....
# .G.hf
# .....
# ffff.
# ..f..
#
# Step 16: Gardener at [0, 1], action: up
# .G...
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 17: Gardener at [0, 2], action: right
# ..G..
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 18: Gardener at [0, 2], action: up
# ..G..
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 19: Gardener at [0, 1], action: left
# .G...
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 20: Gardener at [0, 2], action: right
# ..G..
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 21: Gardener at [0, 3], action: right
# ...G.
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 22: Gardener at [0, 4], action: right
# ....G
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 23: Gardener at [0, 3], action: left
# ...G.
# .h.hf
# .....
# ffff.
# ..f..
#
# Step 24: Gardener at [1, 3], action: down
# .....
# .h.Gf
# .....
# ffff.
# ..f..
#
# Harvested fruit at (1,4)
# Step 25: Gardener at [1, 4], action: right
# .....
# .h.hG
# .....
# ffff.
# ..f..
#
# Episode 2 finished in 25 steps. Total harvested: 3
# ==============================
#
# Episode 3 starting:
# G....
# .f...
# .....
# .f...
# .....
#
# Step 1: Gardener at [0, 0], action: left
# G....
# .f...
# .....
# .f...
# .....
#
# Step 2: Gardener at [0, 1], action: right
# .G...
# .f...
# .....
# .f...
# .....
#
# Step 3: Gardener at [0, 2], action: right
# ..G..
# .f...
# .....
# .f...
# .....
#
# Step 4: Gardener at [1, 2], action: down
# .....
# .fG..
# .....
# .f...
# .....
#
# Step 5: Gardener at [1, 3], action: right
# .....
# .f.G.
# .....
# .f...
# .....
#
# Step 6: Gardener at [1, 2], action: left
# .....
# .fG..
# .....
# .f...
# .....
#
# Step 7: Gardener at [2, 2], action: down
# .....
# .f...
# ..G..
# .f...
# .....
#
# Step 8: Gardener at [3, 2], action: down
# .....
# .f...
# .....
# .fG..
# .....
#
# Step 9: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 10: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 11: Gardener at [3, 2], action: up
# .....
# .f...
# .....
# .fG..
# .....
#
# Step 12: Gardener at [3, 3], action: right
# .....
# .f...
# .....
# .f.G.
# .....
#
# Step 13: Gardener at [3, 2], action: left
# .....
# .f...
# .....
# .fG..
# .....
#
# Step 14: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 15: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 16: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 17: Gardener at [4, 2], action: down
# .....
# .f...
# .....
# .f...
# ..G..
#
# Step 18: Gardener at [4, 1], action: left
# .....
# .f...
# .....
# .f...
# .G...
#
# Step 19: Gardener at [4, 0], action: left
# .....
# .f...
# .....
# .f...
# G....
#
# Step 20: Gardener at [3, 0], action: up
# .....
# .f...
# .....
# Gf...
# .....
#
# Step 21: Gardener at [3, 0], action: left
# .....
# .f...
# .....
# Gf...
# .....
#
# Step 22: Gardener at [4, 0], action: down
# .....
# .f...
# .....
# .f...
# G....
#
# Step 23: Gardener at [4, 0], action: down
# .....
# .f...
# .....
# .f...
# G....
#
# Step 24: Gardener at [4, 1], action: right
# .....
# .f...
# .....
# .f...
# .G...
#
# Step 25: Gardener at [4, 1], action: down
# .....
# .f...
# .....
# .f...
# .G...
#
# Episode 3 finished in 25 steps. Total harvested: 0
# ==============================
#
# Episode 4 starting:
# G.f..
# f..f.
# .ff..
# .f..f
# .....
#
# Harvested fruit at (0,0)
# Step 1: Gardener at [0, 0], action: left
# G.f..
# f..f.
# .ff..
# .f..f
# .....
#
# Harvested fruit at (1,0)
# Step 2: Gardener at [1, 0], action: down
# h.f..
# G..f.
# .ff..
# .f..f
# .....
#
# Step 3: Gardener at [0, 0], action: up
# G.f..
# h..f.
# .ff..
# .f..f
# .....
#
# Step 4: Gardener at [1, 0], action: down
# h.f..
# G..f.
# .ff..
# .f..f
# .....
#
# Step 5: Gardener at [1, 1], action: right
# h.f..
# hG.f.
# .ff..
# .f..f
# .....
#
# Harvested fruit at (2,1)
# Step 6: Gardener at [2, 1], action: down
# h.f..
# h..f.
# .Gf..
# .f..f
# .....
#
# Harvested fruit at (2,2)
# Step 7: Gardener at [2, 2], action: right
# h.f..
# h..f.
# .hG..
# .f..f
# .....
#
# Step 8: Gardener at [2, 3], action: right
# h.f..
# h..f.
# .hhG.
# .f..f
# .....
#
# Harvested fruit at (1,3)
# Step 9: Gardener at [1, 3], action: up
# h.f..
# h..G.
# .hh..
# .f..f
# .....
#
# Step 10: Gardener at [1, 4], action: right
# h.f..
# h..hG
# .hh..
# .f..f
# .....
#
# Step 11: Gardener at [2, 4], action: down
# h.f..
# h..h.
# .hh.G
# .f..f
# .....
#
# Step 12: Gardener at [2, 4], action: right
# h.f..
# h..h.
# .hh.G
# .f..f
# .....
#
# Harvested fruit at (3,4)
# Step 13: Gardener at [3, 4], action: down
# h.f..
# h..h.
# .hh..
# .f..G
# .....
#
# Step 14: Gardener at [3, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..G
# .....
#
# Step 15: Gardener at [3, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..G
# .....
#
# Step 16: Gardener at [3, 3], action: left
# h.f..
# h..h.
# .hh..
# .f.Gh
# .....
#
# Step 17: Gardener at [4, 3], action: down
# h.f..
# h..h.
# .hh..
# .f..h
# ...G.
#
# Step 18: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Step 19: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Step 20: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Step 21: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Step 22: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Step 23: Gardener at [4, 3], action: left
# h.f..
# h..h.
# .hh..
# .f..h
# ...G.
#
# Step 24: Gardener at [4, 3], action: down
# h.f..
# h..h.
# .hh..
# .f..h
# ...G.
#
# Step 25: Gardener at [4, 4], action: right
# h.f..
# h..h.
# .hh..
# .f..h
# ....G
#
# Episode 4 finished in 25 steps. Total harvested: 6
# ==============================
#
# Episode 5 starting:
# Gff..
# .f.f.
# .....
# .....
# ..fff
#
# Step 1: Gardener at [0, 0], action: up
# Gff..
# .f.f.
# .....
# .....
# ..fff
#
# Step 2: Gardener at [1, 0], action: down
# .ff..
# Gf.f.
# .....
# .....
# ..fff
#
# Harvested fruit at (1,1)
# Step 3: Gardener at [1, 1], action: right
# .ff..
# .G.f.
# .....
# .....
# ..fff
#
# Step 4: Gardener at [1, 2], action: right
# .ff..
# .hGf.
# .....
# .....
# ..fff
#
# Harvested fruit at (0,2)
# Step 5: Gardener at [0, 2], action: up
# .fG..
# .h.f.
# .....
# .....
# ..fff
#
# Harvested fruit at (0,1)
# Step 6: Gardener at [0, 1], action: left
# .Gh..
# .h.f.
# .....
# .....
# ..fff
#
# Step 7: Gardener at [0, 1], action: up
# .Gh..
# .h.f.
# .....
# .....
# ..fff
#
# Step 8: Gardener at [0, 1], action: up
# .Gh..
# .h.f.
# .....
# .....
# ..fff
#
# Step 9: Gardener at [1, 1], action: down
# .hh..
# .G.f.
# .....
# .....
# ..fff
#
# Step 10: Gardener at [1, 2], action: right
# .hh..
# .hGf.
# .....
# .....
# ..fff
#
# Step 11: Gardener at [1, 1], action: left
# .hh..
# .G.f.
# .....
# .....
# ..fff
#
# Step 12: Gardener at [1, 0], action: left
# .hh..
# Gh.f.
# .....
# .....
# ..fff
#
# Step 13: Gardener at [0, 0], action: up
# Ghh..
# .h.f.
# .....
# .....
# ..fff
#
# Step 14: Gardener at [1, 0], action: down
# .hh..
# Gh.f.
# .....
# .....
# ..fff
#
# Step 15: Gardener at [1, 1], action: right
# .hh..
# .G.f.
# .....
# .....
# ..fff
#
# Step 16: Gardener at [1, 0], action: left
# .hh..
# Gh.f.
# .....
# .....
# ..fff
#
# Step 17: Gardener at [2, 0], action: down
# .hh..
# .h.f.
# G....
# .....
# ..fff
#
# Step 18: Gardener at [1, 0], action: up
# .hh..
# Gh.f.
# .....
# .....
# ..fff
#
# Step 19: Gardener at [1, 0], action: left
# .hh..
# Gh.f.
# .....
# .....
# ..fff
#
# Step 20: Gardener at [1, 1], action: right
# .hh..
# .G.f.
# .....
# .....
# ..fff
#
# Step 21: Gardener at [1, 2], action: right
# .hh..
# .hGf.
# .....
# .....
# ..fff
#
# Harvested fruit at (1,3)
# Step 22: Gardener at [1, 3], action: right
# .hh..
# .h.G.
# .....
# .....
# ..fff
#
# Step 23: Gardener at [2, 3], action: down
# .hh..
# .h.h.
# ...G.
# .....
# ..fff
#
# Step 24: Gardener at [1, 3], action: up
# .hh..
# .h.G.
# .....
# .....
# ..fff
#
# Step 25: Gardener at [1, 2], action: left
# .hh..
# .hGh.
# .....
# .....
# ..fff
#
# Episode 5 finished in 25 steps. Total harvested: 4
# ==============================
#
# Episode 6 starting:
# G....
# .....
# f....
# .....
# .f.f.
#
# Step 1: Gardener at [0, 0], action: left
# G....
# .....
# f....
# .....
# .f.f.
#
# Step 2: Gardener at [1, 0], action: down
# .....
# G....
# f....
# .....
# .f.f.
#
# Step 3: Gardener at [0, 0], action: up
# G....
# .....
# f....
# .....
# .f.f.
#
# Step 4: Gardener at [1, 0], action: down
# .....
# G....
# f....
# .....
# .f.f.
#
# Step 5: Gardener at [1, 1], action: right
# .....
# .G...
# f....
# .....
# .f.f.
#
# Step 6: Gardener at [1, 0], action: left
# .....
# G....
# f....
# .....
# .f.f.
#
# Step 7: Gardener at [1, 1], action: right
# .....
# .G...
# f....
# .....
# .f.f.
#
# Step 8: Gardener at [2, 1], action: down
# .....
# .....
# fG...
# .....
# .f.f.
#
# Step 9: Gardener at [2, 2], action: right
# .....
# .....
# f.G..
# .....
# .f.f.
#
# Step 10: Gardener at [2, 3], action: right
# .....
# .....
# f..G.
# .....
# .f.f.
#
# Step 11: Gardener at [2, 4], action: right
# .....
# .....
# f...G
# .....
# .f.f.
#
# Step 12: Gardener at [1, 4], action: up
# .....
# ....G
# f....
# .....
# .f.f.
#
# Step 13: Gardener at [1, 3], action: left
# .....
# ...G.
# f....
# .....
# .f.f.
#
# Step 14: Gardener at [2, 3], action: down
# .....
# .....
# f..G.
# .....
# .f.f.
#
# Step 15: Gardener at [3, 3], action: down
# .....
# .....
# f....
# ...G.
# .f.f.
#
# Step 16: Gardener at [3, 4], action: right
# .....
# .....
# f....
# ....G
# .f.f.
#
# Step 17: Gardener at [3, 3], action: left
# .....
# .....
# f....
# ...G.
# .f.f.
#
# Step 18: Gardener at [3, 4], action: right
# .....
# .....
# f....
# ....G
# .f.f.
#
# Step 19: Gardener at [4, 4], action: down
# .....
# .....
# f....
# .....
# .f.fG
#
# Harvested fruit at (4,3)
# Step 20: Gardener at [4, 3], action: left
# .....
# .....
# f....
# .....
# .f.G.
#
# Step 21: Gardener at [3, 3], action: up
# .....
# .....
# f....
# ...G.
# .f.h.
#
# Step 22: Gardener at [3, 4], action: right
# .....
# .....
# f....
# ....G
# .f.h.
#
# Step 23: Gardener at [2, 4], action: up
# .....
# .....
# f...G
# .....
# .f.h.
#
# Step 24: Gardener at [1, 4], action: up
# .....
# ....G
# f....
# .....
# .f.h.
#
# Step 25: Gardener at [1, 4], action: right
# .....
# ....G
# f....
# .....
# .f.h.
#
# Episode 6 finished in 25 steps. Total harvested: 1
# ==============================
#
# Episode 7 starting:
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Harvested fruit at (0,0)
# Step 1: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 2: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 3: Gardener at [0, 0], action: up
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 4: Gardener at [0, 0], action: up
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 5: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 6: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 7: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 8: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 9: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 10: Gardener at [0, 1], action: right
# hG...
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 11: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 12: Gardener at [0, 0], action: left
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 13: Gardener at [1, 0], action: down
# h....
# G.ff.
# ....f
# ..f..
# ...f.
#
# Step 14: Gardener at [0, 0], action: up
# G....
# ..ff.
# ....f
# ..f..
# ...f.
#
# Step 15: Gardener at [1, 0], action: down
# h....
# G.ff.
# ....f
# ..f..
# ...f.
#
# Step 16: Gardener at [2, 0], action: down
# h....
# ..ff.
# G...f
# ..f..
# ...f.
#
# Step 17: Gardener at [1, 0], action: up
# h....
# G.ff.
# ....f
# ..f..
# ...f.
#
# Step 18: Gardener at [1, 1], action: right
# h....
# .Gff.
# ....f
# ..f..
# ...f.
#
# Step 19: Gardener at [1, 0], action: left
# h....
# G.ff.
# ....f
# ..f..
# ...f.
#
# Step 20: Gardener at [1, 1], action: right
# h....
# .Gff.
# ....f
# ..f..
# ...f.
#
# Harvested fruit at (1,2)
# Step 21: Gardener at [1, 2], action: right
# h....
# ..Gf.
# ....f
# ..f..
# ...f.
#
# Step 22: Gardener at [2, 2], action: down
# h....
# ..hf.
# ..G.f
# ..f..
# ...f.
#
# Harvested fruit at (3,2)
# Step 23: Gardener at [3, 2], action: down
# h....
# ..hf.
# ....f
# ..G..
# ...f.
#
# Step 24: Gardener at [4, 2], action: down
# h....
# ..hf.
# ....f
# ..h..
# ..Gf.
#
# Step 25: Gardener at [4, 2], action: down
# h....
# ..hf.
# ....f
# ..h..
# ..Gf.
#
# Episode 7 finished in 25 steps. Total harvested: 3
# ==============================
#
# Episode 8 starting:
# G....
# ..fff
# .....
# ..f..
# .fff.
#
# Step 1: Gardener at [0, 0], action: left
# G....
# ..fff
# .....
# ..f..
# .fff.
#
# Step 2: Gardener at [1, 0], action: down
# .....
# G.fff
# .....
# ..f..
# .fff.
#
# Step 3: Gardener at [1, 0], action: left
# .....
# G.fff
# .....
# ..f..
# .fff.
#
# Step 4: Gardener at [1, 1], action: right
# .....
# .Gfff
# .....
# ..f..
# .fff.
#
# Step 5: Gardener at [1, 0], action: left
# .....
# G.fff
# .....
# ..f..
# .fff.
#
# Step 6: Gardener at [0, 0], action: up
# G....
# ..fff
# .....
# ..f..
# .fff.
#
# Step 7: Gardener at [0, 0], action: up
# G....
# ..fff
# .....
# ..f..
# .fff.
#
# Step 8: Gardener at [1, 0], action: down
# .....
# G.fff
# .....
# ..f..
# .fff.
#
# Step 9: Gardener at [1, 1], action: right
# .....
# .Gfff
# .....
# ..f..
# .fff.
#
# Step 10: Gardener at [1, 0], action: left
# .....
# G.fff
# .....
# ..f..
# .fff.
#
# Step 11: Gardener at [1, 1], action: right
# .....
# .Gfff
# .....
# ..f..
# .fff.
#
# Harvested fruit at (1,2)
# Step 12: Gardener at [1, 2], action: right
# .....
# ..Gff
# .....
# ..f..
# .fff.
#
# Harvested fruit at (1,3)
# Step 13: Gardener at [1, 3], action: right
# .....
# ..hGf
# .....
# ..f..
# .fff.
#
# Harvested fruit at (1,4)
# Step 14: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 15: Gardener at [1, 3], action: left
# .....
# ..hGh
# .....
# ..f..
# .fff.
#
# Step 16: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 17: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 18: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 19: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 20: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 21: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 22: Gardener at [1, 3], action: left
# .....
# ..hGh
# .....
# ..f..
# .fff.
#
# Step 23: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 24: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Step 25: Gardener at [1, 4], action: right
# .....
# ..hhG
# .....
# ..f..
# .fff.
#
# Episode 8 finished in 25 steps. Total harvested: 3
# ==============================
#
# Episode 9 starting:
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Harvested fruit at (0,0)
# Step 1: Gardener at [0, 0], action: left
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 2: Gardener at [0, 0], action: left
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 3: Gardener at [0, 0], action: up
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 4: Gardener at [0, 1], action: right
# hG...
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 5: Gardener at [0, 0], action: left
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 6: Gardener at [0, 0], action: left
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 7: Gardener at [1, 0], action: down
# h....
# G.f.f
# .....
# ..ff.
# ff.f.
#
# Step 8: Gardener at [0, 0], action: up
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 9: Gardener at [0, 0], action: left
# G....
# ..f.f
# .....
# ..ff.
# ff.f.
#
# Step 10: Gardener at [1, 0], action: down
# h....
# G.f.f
# .....
# ..ff.
# ff.f.
#
# Step 11: Gardener at [1, 0], action: left
# h....
# G.f.f
# .....
# ..ff.
# ff.f.
#
# Step 12: Gardener at [1, 1], action: right
# h....
# .Gf.f
# .....
# ..ff.
# ff.f.
#
# Step 13: Gardener at [2, 1], action: down
# h....
# ..f.f
# .G...
# ..ff.
# ff.f.
#
# Step 14: Gardener at [2, 2], action: right
# h....
# ..f.f
# ..G..
# ..ff.
# ff.f.
#
# Harvested fruit at (3,2)
# Step 15: Gardener at [3, 2], action: down
# h....
# ..f.f
# .....
# ..Gf.
# ff.f.
#
# Harvested fruit at (3,3)
# Step 16: Gardener at [3, 3], action: right
# h....
# ..f.f
# .....
# ..hG.
# ff.f.
#
# Step 17: Gardener at [3, 2], action: left
# h....
# ..f.f
# .....
# ..Gh.
# ff.f.
#
# Step 18: Gardener at [3, 1], action: left
# h....
# ..f.f
# .....
# .Ghh.
# ff.f.
#
# Harvested fruit at (4,1)
# Step 19: Gardener at [4, 1], action: down
# h....
# ..f.f
# .....
# ..hh.
# fG.f.
#
# Harvested fruit at (4,0)
# Step 20: Gardener at [4, 0], action: left
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Step 21: Gardener at [4, 0], action: left
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Step 22: Gardener at [4, 0], action: down
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Step 23: Gardener at [4, 0], action: left
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Step 24: Gardener at [4, 0], action: left
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Step 25: Gardener at [4, 0], action: left
# h....
# ..f.f
# .....
# ..hh.
# Gh.f.
#
# Episode 9 finished in 25 steps. Total harvested: 5
# ==============================
#
# Episode 10 starting:
# G.f..
# .....
# ..f..
# f....
# ...f.
#
# Step 1: Gardener at [1, 0], action: down
# ..f..
# G....
# ..f..
# f....
# ...f.
#
# Step 2: Gardener at [1, 1], action: right
# ..f..
# .G...
# ..f..
# f....
# ...f.
#
# Step 3: Gardener at [2, 1], action: down
# ..f..
# .....
# .Gf..
# f....
# ...f.
#
# Harvested fruit at (2,2)
# Step 4: Gardener at [2, 2], action: right
# ..f..
# .....
# ..G..
# f....
# ...f.
#
# Step 5: Gardener at [2, 1], action: left
# ..f..
# .....
# .Gh..
# f....
# ...f.
#
# Step 6: Gardener at [2, 2], action: right
# ..f..
# .....
# ..G..
# f....
# ...f.
#
# Step 7: Gardener at [2, 3], action: right
# ..f..
# .....
# ..hG.
# f....
# ...f.
#
# Step 8: Gardener at [2, 4], action: right
# ..f..
# .....
# ..h.G
# f....
# ...f.
#
# Step 9: Gardener at [3, 4], action: down
# ..f..
# .....
# ..h..
# f...G
# ...f.
#
# Step 10: Gardener at [3, 3], action: left
# ..f..
# .....
# ..h..
# f..G.
# ...f.
#
# Step 11: Gardener at [3, 2], action: left
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 12: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 13: Gardener at [3, 2], action: right
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 14: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 15: Gardener at [3, 2], action: right
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 16: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 17: Gardener at [3, 2], action: right
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 18: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 19: Gardener at [3, 2], action: right
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 20: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 21: Gardener at [3, 2], action: right
# ..f..
# .....
# ..h..
# f.G..
# ...f.
#
# Step 22: Gardener at [3, 1], action: left
# ..f..
# .....
# ..h..
# fG...
# ...f.
#
# Step 23: Gardener at [2, 1], action: up
# ..f..
# .....
# .Gh..
# f....
# ...f.
#
# Step 24: Gardener at [1, 1], action: up
# ..f..
# .G...
# ..h..
# f....
# ...f.
#
# Step 25: Gardener at [2, 1], action: down
# ..f..
# .....
# .Gh..
# f....
# ...f.
#
# Episode 10 finished in 25 steps. Total harvested: 1
# ==============================
#
# Episode 11 starting:
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 1: Gardener at [0, 0], action: left
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 2: Gardener at [0, 0], action: left
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 3: Gardener at [0, 0], action: left
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 4: Gardener at [0, 0], action: left
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 5: Gardener at [0, 0], action: left
# G..f.
# .f...
# ...f.
# ...ff
# .f..f
#
# Step 6: Gardener at [1, 0], action: down
# ...f.
# Gf...
# ...f.
# ...ff
# .f..f
#
# Harvested fruit at (1,1)
# Step 7: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 8: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 9: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 10: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 11: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 12: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 13: Gardener at [0, 0], action: up
# G..f.
# .h...
# ...f.
# ...ff
# .f..f
#
# Step 14: Gardener at [1, 0], action: down
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 15: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 16: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 17: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 18: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 19: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 20: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 21: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 22: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 23: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Step 24: Gardener at [1, 0], action: left
# ...f.
# Gh...
# ...f.
# ...ff
# .f..f
#
# Step 25: Gardener at [1, 1], action: right
# ...f.
# .G...
# ...f.
# ...ff
# .f..f
#
# Episode 11 finished in 25 steps. Total harvested: 1
# ==============================
#
# Episode 12 starting:
# G....
# f....
# .f...
# fff.f
# ...f.
#
# Harvested fruit at (1,0)
# Step 1: Gardener at [1, 0], action: down
# f....
# G....
# .f...
# fff.f
# ...f.
#
# Step 2: Gardener at [1, 1], action: right
# f....
# hG...
# .f...
# fff.f
# ...f.
#
# Step 3: Gardener at [0, 1], action: up
# fG...
# h....
# .f...
# fff.f
# ...f.
#
# Step 4: Gardener at [0, 2], action: right
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 5: Gardener at [0, 2], action: up
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 6: Gardener at [0, 2], action: up
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 7: Gardener at [0, 2], action: up
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 8: Gardener at [0, 2], action: up
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 9: Gardener at [0, 2], action: up
# f.G..
# h....
# .f...
# fff.f
# ...f.
#
# Step 10: Gardener at [0, 3], action: right
# f..G.
# h....
# .f...
# fff.f
# ...f.
#
# Step 11: Gardener at [1, 3], action: down
# f....
# h..G.
# .f...
# fff.f
# ...f.
#
# Step 12: Gardener at [1, 4], action: right
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 13: Gardener at [1, 4], action: right
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 14: Gardener at [1, 4], action: right
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 15: Gardener at [0, 4], action: up
# f...G
# h....
# .f...
# fff.f
# ...f.
#
# Step 16: Gardener at [1, 4], action: down
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 17: Gardener at [0, 4], action: up
# f...G
# h....
# .f...
# fff.f
# ...f.
#
# Step 18: Gardener at [0, 4], action: right
# f...G
# h....
# .f...
# fff.f
# ...f.
#
# Step 19: Gardener at [1, 4], action: down
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 20: Gardener at [0, 4], action: up
# f...G
# h....
# .f...
# fff.f
# ...f.
#
# Step 21: Gardener at [1, 4], action: down
# f....
# h...G
# .f...
# fff.f
# ...f.
#
# Step 22: Gardener at [2, 4], action: down
# f....
# h....
# .f..G
# fff.f
# ...f.
#
# Harvested fruit at (3,4)
# Step 23: Gardener at [3, 4], action: down
# f....
# h....
# .f...
# fff.G
# ...f.
#
# Step 24: Gardener at [2, 4], action: up
# f....
# h....
# .f..G
# fff.h
# ...f.
#
# Step 25: Gardener at [1, 4], action: up
# f....
# h...G
# .f...
# fff.h
# ...f.
#
# Episode 12 finished in 25 steps. Total harvested: 2
# ==============================
#
# Episode 13 starting:
# G..ff
# ....f
# .f...
# ...f.
# f.f..
#
# Step 1: Gardener at [1, 0], action: down
# f..ff
# G...f
# .f...
# ...f.
# f.f..
#
# Step 2: Gardener at [1, 1], action: right
# f..ff
# .G..f
# .f...
# ...f.
# f.f..
#
# Step 3: Gardener at [1, 2], action: right
# f..ff
# ..G.f
# .f...
# ...f.
# f.f..
#
# Step 4: Gardener at [1, 3], action: right
# f..ff
# ...Gf
# .f...
# ...f.
# f.f..
#
# Step 5: Gardener at [1, 2], action: left
# f..ff
# ..G.f
# .f...
# ...f.
# f.f..
#
# Step 6: Gardener at [1, 3], action: right
# f..ff
# ...Gf
# .f...
# ...f.
# f.f..
#
# Harvested fruit at (1,4)
# Step 7: Gardener at [1, 4], action: right
# f..ff
# ....G
# .f...
# ...f.
# f.f..
#
# Harvested fruit at (0,4)
# Step 8: Gardener at [0, 4], action: up
# f..fG
# ....h
# .f...
# ...f.
# f.f..
#
# Step 9: Gardener at [1, 4], action: down
# f..fh
# ....G
# .f...
# ...f.
# f.f..
#
# Step 10: Gardener at [2, 4], action: down
# f..fh
# ....h
# .f..G
# ...f.
# f.f..
#
# Step 11: Gardener at [3, 4], action: down
# f..fh
# ....h
# .f...
# ...fG
# f.f..
#
# Step 12: Gardener at [4, 4], action: down
# f..fh
# ....h
# .f...
# ...f.
# f.f.G
#
# Step 13: Gardener at [4, 3], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.fG.
#
# Step 14: Gardener at [4, 4], action: right
# f..fh
# ....h
# .f...
# ...f.
# f.f.G
#
# Step 15: Gardener at [4, 3], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.fG.
#
# Step 16: Gardener at [4, 4], action: right
# f..fh
# ....h
# .f...
# ...f.
# f.f.G
#
# Step 17: Gardener at [4, 3], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.fG.
#
# Step 18: Gardener at [4, 4], action: right
# f..fh
# ....h
# .f...
# ...f.
# f.f.G
#
# Step 19: Gardener at [4, 3], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.fG.
#
# Step 20: Gardener at [4, 4], action: right
# f..fh
# ....h
# .f...
# ...f.
# f.f.G
#
# Step 21: Gardener at [4, 3], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.fG.
#
# Harvested fruit at (4,2)
# Step 22: Gardener at [4, 2], action: left
# f..fh
# ....h
# .f...
# ...f.
# f.G..
#
# Step 23: Gardener at [4, 2], action: down
# f..fh
# ....h
# .f...
# ...f.
# f.G..
#
# Step 24: Gardener at [4, 2], action: down
# f..fh
# ....h
# .f...
# ...f.
# f.G..
#
# Step 25: Gardener at [4, 2], action: down
# f..fh
# ....h
# .f...
# ...f.
# f.G..
#
# Episode 13 finished in 25 steps. Total harvested: 3
# ==============================
#
# Episode 14 starting:
# Gf...
# .f...
# .....
# .ff..
# ..f..
#
# Step 1: Gardener at [1, 0], action: down
# .f...
# Gf...
# .....
# .ff..
# ..f..
#
# Harvested fruit at (1,1)
# Step 2: Gardener at [1, 1], action: right
# .f...
# .G...
# .....
# .ff..
# ..f..
#
# Step 3: Gardener at [1, 2], action: right
# .f...
# .hG..
# .....
# .ff..
# ..f..
#
# Step 4: Gardener at [1, 3], action: right
# .f...
# .h.G.
# .....
# .ff..
# ..f..
#
# Step 5: Gardener at [1, 4], action: right
# .f...
# .h..G
# .....
# .ff..
# ..f..
#
# Step 6: Gardener at [2, 4], action: down
# .f...
# .h...
# ....G
# .ff..
# ..f..
#
# Step 7: Gardener at [3, 4], action: down
# .f...
# .h...
# .....
# .ff.G
# ..f..
#
# Step 8: Gardener at [4, 4], action: down
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 9: Gardener at [3, 4], action: up
# .f...
# .h...
# .....
# .ff.G
# ..f..
#
# Step 10: Gardener at [4, 4], action: down
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 11: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 12: Gardener at [4, 4], action: down
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 13: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 14: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 15: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 16: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 17: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 18: Gardener at [4, 4], action: right
# .f...
# .h...
# .....
# .ff..
# ..f.G
#
# Step 19: Gardener at [4, 3], action: left
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 20: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 21: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 22: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 23: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 24: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Step 25: Gardener at [4, 3], action: down
# .f...
# .h...
# .....
# .ff..
# ..fG.
#
# Episode 14 finished in 25 steps. Total harvested: 1
# ==============================
#
# Episode 15 starting:
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 1: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 2: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 3: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 4: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 5: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 6: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 7: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 8: Gardener at [0, 0], action: left
# G....
# .....
# ..f.f
# f....
# ....f
#
# Step 9: Gardener at [0, 1], action: right
# .G...
# .....
# ..f.f
# f....
# ....f
#
# Step 10: Gardener at [1, 1], action: down
# .....
# .G...
# ..f.f
# f....
# ....f
#
# Step 11: Gardener at [1, 2], action: right
# .....
# ..G..
# ..f.f
# f....
# ....f
#
# Step 12: Gardener at [1, 3], action: right
# .....
# ...G.
# ..f.f
# f....
# ....f
#
# Step 13: Gardener at [1, 2], action: left
# .....
# ..G..
# ..f.f
# f....
# ....f
#
# Step 14: Gardener at [0, 2], action: up
# ..G..
# .....
# ..f.f
# f....
# ....f
#
# Step 15: Gardener at [0, 1], action: left
# .G...
# .....
# ..f.f
# f....
# ....f
#
# Step 16: Gardener at [1, 1], action: down
# .....
# .G...
# ..f.f
# f....
# ....f
#
# Step 17: Gardener at [1, 2], action: right
# .....
# ..G..
# ..f.f
# f....
# ....f
#
# Harvested fruit at (2,2)
# Step 18: Gardener at [2, 2], action: down
# .....
# .....
# ..G.f
# f....
# ....f
#
# Step 19: Gardener at [2, 1], action: left
# .....
# .....
# .Gh.f
# f....
# ....f
#
# Step 20: Gardener at [2, 0], action: left
# .....
# .....
# G.h.f
# f....
# ....f
#
# Step 21: Gardener at [2, 1], action: right
# .....
# .....
# .Gh.f
# f....
# ....f
#
# Step 22: Gardener at [2, 0], action: left
# .....
# .....
# G.h.f
# f....
# ....f
#
# Step 23: Gardener at [2, 0], action: left
# .....
# .....
# G.h.f
# f....
# ....f
#
# Step 24: Gardener at [2, 0], action: left
# .....
# .....
# G.h.f
# f....
# ....f
#
# Step 25: Gardener at [2, 1], action: right
# .....
# .....
# .Gh.f
# f....
# ....f
#
# Episode 15 finished in 25 steps. Total harvested: 1
# ==============================
#
# Episode 16 starting:
# G....
# ...f.
# f....
# f.f..
# .f...
#
# Step 1: Gardener at [1, 0], action: down
# f....
# G..f.
# f....
# f.f..
# .f...
#
# Step 2: Gardener at [1, 1], action: right
# f....
# .G.f.
# f....
# f.f..
# .f...
#
# Step 3: Gardener at [1, 2], action: right
# f....
# ..Gf.
# f....
# f.f..
# .f...
#
# Step 4: Gardener at [2, 2], action: down
# f....
# ...f.
# f.G..
# f.f..
# .f...
#
# Step 5: Gardener at [2, 1], action: left
# f....
# ...f.
# fG...
# f.f..
# .f...
#
# Harvested fruit at (2,0)
# Step 6: Gardener at [2, 0], action: left
# f....
# ...f.
# G....
# f.f..
# .f...
#
# Step 7: Gardener at [2, 1], action: right
# f....
# ...f.
# hG...
# f.f..
# .f...
#
# Step 8: Gardener at [3, 1], action: down
# f....
# ...f.
# h....
# fGf..
# .f...
#
# Harvested fruit at (3,2)
# Step 9: Gardener at [3, 2], action: right
# f....
# ...f.
# h....
# f.G..
# .f...
#
# Step 10: Gardener at [3, 3], action: right
# f....
# ...f.
# h....
# f.hG.
# .f...
#
# Step 11: Gardener at [3, 4], action: right
# f....
# ...f.
# h....
# f.h.G
# .f...
#
# Step 12: Gardener at [3, 3], action: left
# f....
# ...f.
# h....
# f.hG.
# .f...
#
# Step 13: Gardener at [3, 2], action: left
# f....
# ...f.
# h....
# f.G..
# .f...
#
# Step 14: Gardener at [4, 2], action: down
# f....
# ...f.
# h....
# f.h..
# .fG..
#
# Step 15: Gardener at [4, 3], action: right
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Step 16: Gardener at [4, 4], action: right
# f....
# ...f.
# h....
# f.h..
# .f..G
#
# Step 17: Gardener at [4, 3], action: left
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Step 18: Gardener at [4, 4], action: right
# f....
# ...f.
# h....
# f.h..
# .f..G
#
# Step 19: Gardener at [4, 3], action: left
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Step 20: Gardener at [4, 4], action: right
# f....
# ...f.
# h....
# f.h..
# .f..G
#
# Step 21: Gardener at [4, 3], action: left
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Step 22: Gardener at [4, 2], action: left
# f....
# ...f.
# h....
# f.h..
# .fG..
#
# Step 23: Gardener at [4, 3], action: right
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Step 24: Gardener at [4, 4], action: right
# f....
# ...f.
# h....
# f.h..
# .f..G
#
# Step 25: Gardener at [4, 3], action: left
# f....
# ...f.
# h....
# f.h..
# .f.G.
#
# Episode 16 finished in 25 steps. Total harvested: 2
# ==============================
#
# Episode 17 starting:
# G....
# ..f..
# ...f.
# ....f
# ....f
#
# Step 1: Gardener at [1, 0], action: down
# .....
# G.f..
# ...f.
# ....f
# ....f
#
# Step 2: Gardener at [1, 1], action: right
# .....
# .Gf..
# ...f.
# ....f
# ....f
#
# Step 3: Gardener at [1, 0], action: left
# .....
# G.f..
# ...f.
# ....f
# ....f
#
# Step 4: Gardener at [1, 1], action: right
# .....
# .Gf..
# ...f.
# ....f
# ....f
#
# Harvested fruit at (1,2)
# Step 5: Gardener at [1, 2], action: right
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 6: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 7: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 8: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 9: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 10: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 11: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 12: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 13: Gardener at [0, 3], action: up
# ...G.
# ..h..
# ...f.
# ....f
# ....f
#
# Step 14: Gardener at [1, 3], action: down
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 15: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 16: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 17: Gardener at [0, 3], action: up
# ...G.
# ..h..
# ...f.
# ....f
# ....f
#
# Step 18: Gardener at [1, 3], action: down
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 19: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 20: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Step 21: Gardener at [1, 2], action: left
# .....
# ..G..
# ...f.
# ....f
# ....f
#
# Step 22: Gardener at [1, 3], action: right
# .....
# ..hG.
# ...f.
# ....f
# ....f
#
# Harvested fruit at (2,3)
# Step 23: Gardener at [2, 3], action: down
# .....
# ..h..
# ...G.
# ....f
# ....f
#
# Step 24: Gardener at [2, 4], action: right
# .....
# ..h..
# ...hG
# ....f
# ....f
#
# Step 25: Gardener at [2, 4], action: right
# .....
# ..h..
# ...hG
# ....f
# ....f
#
# Episode 17 finished in 25 steps. Total harvested: 2
# ==============================
#
# Episode 18 starting:
# G....
# ..ff.
# ....f
# .....
# .....
#
# Step 1: Gardener at [1, 0], action: down
# .....
# G.ff.
# ....f
# .....
# .....
#
# Step 2: Gardener at [1, 1], action: right
# .....
# .Gff.
# ....f
# .....
# .....
#
# Harvested fruit at (1,2)
# Step 3: Gardener at [1, 2], action: right
# .....
# ..Gf.
# ....f
# .....
# .....
#
# Step 4: Gardener at [0, 2], action: up
# ..G..
# ..hf.
# ....f
# .....
# .....
#
# Step 5: Gardener at [1, 2], action: down
# .....
# ..Gf.
# ....f
# .....
# .....
#
# Step 6: Gardener at [2, 2], action: down
# .....
# ..hf.
# ..G.f
# .....
# .....
#
# Step 7: Gardener at [3, 2], action: down
# .....
# ..hf.
# ....f
# ..G..
# .....
#
# Step 8: Gardener at [4, 2], action: down
# .....
# ..hf.
# ....f
# .....
# ..G..
#
# Step 9: Gardener at [3, 2], action: up
# .....
# ..hf.
# ....f
# ..G..
# .....
#
# Step 10: Gardener at [2, 2], action: up
# .....
# ..hf.
# ..G.f
# .....
# .....
#
# Step 11: Gardener at [1, 2], action: up
# .....
# ..Gf.
# ....f
# .....
# .....
#
# Harvested fruit at (1,3)
# Step 12: Gardener at [1, 3], action: right
# .....
# ..hG.
# ....f
# .....
# .....
#
# Step 13: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 14: Gardener at [1, 3], action: down
# .....
# ..hG.
# ....f
# .....
# .....
#
# Step 15: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 16: Gardener at [1, 3], action: down
# .....
# ..hG.
# ....f
# .....
# .....
#
# Step 17: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 18: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 19: Gardener at [1, 3], action: down
# .....
# ..hG.
# ....f
# .....
# .....
#
# Step 20: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 21: Gardener at [1, 3], action: down
# .....
# ..hG.
# ....f
# .....
# .....
#
# Step 22: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 23: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 24: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Step 25: Gardener at [0, 3], action: up
# ...G.
# ..hh.
# ....f
# .....
# .....
#
# Episode 18 finished in 25 steps. Total harvested: 2
# ==============================
#
# Episode 19 starting:
# Gff..
# ..f..
# .....
# ....f
# ...f.
#
# Step 1: Gardener at [1, 0], action: down
# .ff..
# G.f..
# .....
# ....f
# ...f.
#
# Step 2: Gardener at [1, 1], action: right
# .ff..
# .Gf..
# .....
# ....f
# ...f.
#
# Harvested fruit at (1,2)
# Step 3: Gardener at [1, 2], action: right
# .ff..
# ..G..
# .....
# ....f
# ...f.
#
# Step 4: Gardener at [1, 3], action: right
# .ff..
# ..hG.
# .....
# ....f
# ...f.
#
# Step 5: Gardener at [1, 2], action: left
# .ff..
# ..G..
# .....
# ....f
# ...f.
#
# Step 6: Gardener at [1, 3], action: right
# .ff..
# ..hG.
# .....
# ....f
# ...f.
#
# Step 7: Gardener at [2, 3], action: down
# .ff..
# ..h..
# ...G.
# ....f
# ...f.
#
# Step 8: Gardener at [2, 4], action: right
# .ff..
# ..h..
# ....G
# ....f
# ...f.
#
# Harvested fruit at (3,4)
# Step 9: Gardener at [3, 4], action: down
# .ff..
# ..h..
# .....
# ....G
# ...f.
#
# Step 10: Gardener at [4, 4], action: down
# .ff..
# ..h..
# .....
# ....h
# ...fG
#
# Harvested fruit at (4,3)
# Step 11: Gardener at [4, 3], action: left
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 12: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 13: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 14: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 15: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 16: Gardener at [4, 2], action: left
# .ff..
# ..h..
# .....
# ....h
# ..Gh.
#
# Step 17: Gardener at [4, 3], action: right
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 18: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 19: Gardener at [4, 2], action: left
# .ff..
# ..h..
# .....
# ....h
# ..Gh.
#
# Step 20: Gardener at [4, 3], action: right
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 21: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 22: Gardener at [4, 3], action: down
# .ff..
# ..h..
# .....
# ....h
# ...G.
#
# Step 23: Gardener at [4, 2], action: left
# .ff..
# ..h..
# .....
# ....h
# ..Gh.
#
# Step 24: Gardener at [4, 2], action: down
# .ff..
# ..h..
# .....
# ....h
# ..Gh.
#
# Step 25: Gardener at [4, 2], action: down
# .ff..
# ..h..
# .....
# ....h
# ..Gh.
#
# Episode 19 finished in 25 steps. Total harvested: 3
# ==============================
#
# Episode 20 starting:
# G....
# .f..f
# f..f.
# .....
# .....
#
# Step 1: Gardener at [1, 0], action: down
# .....
# Gf..f
# f..f.
# .....
# .....
#
# Harvested fruit at (1,1)
# Step 2: Gardener at [1, 1], action: right
# .....
# .G..f
# f..f.
# .....
# .....
#
# Step 3: Gardener at [1, 2], action: right
# .....
# .hG.f
# f..f.
# .....
# .....
#
# Step 4: Gardener at [1, 3], action: right
# .....
# .h.Gf
# f..f.
# .....
# .....
#
# Step 5: Gardener at [0, 3], action: up
# ...G.
# .h..f
# f..f.
# .....
# .....
#
# Step 6: Gardener at [1, 3], action: down
# .....
# .h.Gf
# f..f.
# .....
# .....
#
# Harvested fruit at (2,3)
# Step 7: Gardener at [2, 3], action: down
# .....
# .h..f
# f..G.
# .....
# .....
#
# Step 8: Gardener at [2, 4], action: right
# .....
# .h..f
# f..hG
# .....
# .....
#
# Step 9: Gardener at [2, 4], action: right
# .....
# .h..f
# f..hG
# .....
# .....
#
# Step 10: Gardener at [3, 4], action: down
# .....
# .h..f
# f..h.
# ....G
# .....
#
# Step 11: Gardener at [4, 4], action: down
# .....
# .h..f
# f..h.
# .....
# ....G
#
# Step 12: Gardener at [4, 4], action: right
# .....
# .h..f
# f..h.
# .....
# ....G
#
# Step 13: Gardener at [4, 3], action: left
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 14: Gardener at [4, 3], action: down
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 15: Gardener at [4, 3], action: down
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 16: Gardener at [4, 3], action: down
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 17: Gardener at [4, 3], action: down
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 18: Gardener at [4, 4], action: right
# .....
# .h..f
# f..h.
# .....
# ....G
#
# Step 19: Gardener at [4, 3], action: left
# .....
# .h..f
# f..h.
# .....
# ...G.
#
# Step 20: Gardener at [4, 2], action: left
# .....
# .h..f
# f..h.
# .....
# ..G..
#
# Step 21: Gardener at [3, 2], action: up
# .....
# .h..f
# f..h.
# ..G..
# .....
#
# Step 22: Gardener at [3, 1], action: left
# .....
# .h..f
# f..h.
# .G...
# .....
#
# Step 23: Gardener at [2, 1], action: up
# .....
# .h..f
# fG.h.
# .....
# .....
#
# Step 24: Gardener at [1, 1], action: up
# .....
# .G..f
# f..h.
# .....
# .....
#
# Step 25: Gardener at [0, 1], action: up
# .G...
# .h..f
# f..h.
# .....
# .....
#
# Episode 20 finished in 25 steps. Total harvested: 2
# ==============================

# %%
# !git init
